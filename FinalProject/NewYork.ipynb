# %% [markdown]
# Setting up to read the Data of the first 5.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

data = dict()
df = pd.read_csv(
    'data/NewYork.csv',
     index_col='PERP_RACE', 
     parse_dates=True
)
df.head(5)
# Out:
#                 INCIDENT_KEY  OCCUR_DATE           BORO  PRECINCT  \
# PERP_RACE
# UNKNOWN            201575314   8/23/2019         QUEENS       103
# BLACK              205748546  11/27/2019          BRONX        40
# WHITE HISPANIC     193118596    2/2/2019      MANHATTAN        23
# BLACK              204192600  10/24/2019  STATEN ISLAND       121
# BLACK HISPANIC     201483468   8/22/2019          BRONX        46
#
#                 JURISDICTION_CODE LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# PERP_RACE
# UNKNOWN                         0           NaN                    False
# BLACK                           0           NaN                    False
# WHITE HISPANIC                  0           NaN                    False
# BLACK                           0     PVT HOUSE                     True
# BLACK HISPANIC                  0           NaN                    False
#
#                PERP_AGE_GROUP PERP_SEX VIC_AGE_GROUP VIC_SEX        VIC_RACE
# PERP_RACE
# ...

# %% [markdown]
# Step 1: Shows how many lines of data this csv contains and what all the columms are named.

# %%
df.count()
# Out:
# INCIDENT_KEY               23568
# OCCUR_DATE                 23568
# BORO                       23568
# PRECINCT                   23568
# JURISDICTION_CODE          23568
# LOCATION_DESC               9987
# STATISTICAL_MURDER_FLAG    23568
# PERP_AGE_GROUP             23568
# PERP_SEX                   23568
# VIC_AGE_GROUP              23568
# VIC_SEX                    23568
# VIC_RACE                   23568
# dtype: int64

# %% [markdown]
# Step 2: I want to add the sums of each race category and add them up so you can see which is the most, but dont know how to do that on here.

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='PERP_RACE'>

# %% [markdown]
# Re-ordering the data so that all PERP_SEX is in ascending order

# %%
df[df.PERP_SEX == 'F'].sort_values(by='OCCUR_DATE', ascending=True).head(10)
# Out:
#                 INCIDENT_KEY OCCUR_DATE      BORO  PRECINCT  \
# PERP_RACE
# BLACK               55346826   1/1/2009  BROOKLYN        75
# BLACK              206898907   1/1/2020     BRONX        43
# BLACK               94424905  1/10/2014     BRONX        46
# BLACK               94424905  1/10/2014     BRONX        46
# BLACK               94424905  1/10/2014     BRONX        46
# BLACK               94424905  1/10/2014     BRONX        46
# BLACK               76795617  1/11/2011  BROOKLYN        73
# BLACK              192301917  1/14/2019  BROOKLYN        75
# WHITE HISPANIC      88638007  1/18/2013     BRONX        49
# WHITE HISPANIC     208187328  1/19/2020     BRONX        46
#
#                 JURISDICTION_CODE              LOCATION_DESC  \
# PERP_RACE
# BLACK                           0    MULTI DWELL - APT BUILD
# BLACK                           0  MULTI DWELL - PUBLIC HOUS
# BLACK                           0    MULTI DWELL - APT BUILD
# ...
